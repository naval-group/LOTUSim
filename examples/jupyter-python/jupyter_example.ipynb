# %%
import rclpy
from rclpy.node import Node
from rclpy.action import ActionClient

from std_msgs.msg import String
from geometry_msgs.msg import Pose
from geographic_msgs.msg import GeoPoint
from lotusim_msgs.msg import MASCmd as MASCmdMsg, VesselPositionArray
from lotusim_msgs.action import MASCmd

# %% [markdown]
# Currently, the model is generated by model string and not looked up through the assets. This is due to the lotusim_params section that is customized.

# %% [markdown]
# The messages (string,MASCmd,VesselPositionArray) are in the interface folder. Please open it.
#
# In MASCmd, the message is divided into goal, result, feedback while its running. We are mainly interested in the goal and result msg
# ```
# std_msgs/Header header
# MASCmd cmd
# ---
# bool result
# string name
# uint16 entity
# ---
# bool fb
# ```
#
# Each message is treated like a class variable. To access the MASCmd under goal, use `msg.cmd` too access.
#
# Below are example of publisher, subscriber and action server.

# %%
class ExampleNode(Node):
    def __init__(self):
        super().__init__('example_node')
        self.pose_subscription = self.create_subscription(
            VesselPositionArray,
            'lotusim/poses',
            self.poses_callback,
            10)
        self.random_publisher = self.create_publisher(String, 'topic', 10)
        self.mas_action_client = ActionClient(self, MASCmd, '/lotusim/mas_cmd')

    def poses_callback(self, msg):
        for vessel_position in msg.vessels:
                lat = vessel_position.geo_point.latitude
                long = vessel_position.geo_point.longitude
                self.get_logger().info(
                    f"Vessel: {vessel_position.vessel_name} | latitude: {lat:.5f} | longitude: {long:.5f} "
                )


    def send_rando_string(self):
        msg = String()
        self.random_publisher.publish(msg)
    
    def send_mas_cmd(self):
        goal_msg = MASCmd.Goal()
       
        msg = MASCmdMsg()
        msg.cmd_type =  MASCmdMsg.CREATE_CMD
        msg.model_name =  "dtmb_hull"
        msg.vessel_name =  "dtmb1"        
        latlong_msg = GeoPoint()
        latlong_msg.latitude = 1.2605794416293148
        latlong_msg.longitude = 103.7516212463379
        latlong_msg.altitude = 0.0
        msg.geo_point = latlong_msg
        
        msg.sdf_string = """
<lotus_param>
    <waypoint_follower>
        <follower>
            <loop>true</loop>
            <linear_accel_limit>0.5</linear_accel_limit>
            <angular_accel_limit>0.005</angular_accel_limit>
            <angular_velocities_limits>0.01</angular_velocities_limits>
            <range_tolerance>2</range_tolerance>
            <circle>
                <radius>10</radius>
            </circle>
        </follower>
    </waypoint_follower>
</lotus_param>
"""

        goal_msg.cmd = msg

        self.mas_action_client.wait_for_server()

        return self.mas_action_client.send_goal_async(goal_msg)


def main(args=None):
    if not rclpy.ok(): 
        rclpy.init(args=args)

    node = ExampleNode()
    node.send_mas_cmd()

    try:
        rclpy.spin(node)
    except KeyboardInterrupt:
        node.get_logger().info("Shutting down...")
    finally:
        node.destroy_node()
        rclpy.shutdown()

# %%
main()
# Out:
# [WARN] [1756130388.074746781] [rcl.logging_rosout]: Publisher already registered for provided node name. If this is due to multiple nodes with the same name then all logs for that logger name will go out over the existing publisher. As soon as any node with that name is destructed it will unregister the publisher, preventing any further logs for that name from being published on the rosout topic.

# %%
class Drone(Agent):
# Herits form Agent
def __init__(…):
super().__init__(…)

###############################################
# Data from sensors
################################################
self.imu = self.create_subscription(
    IMU,
    f"/{world_name}/lrauv{num}/imu", self.poses_callback, 10
)

self.camera = self.create_subscription(
    Img, f"/{world_name}/lrauv{num}/camera", self.camera_callback, 10)

###############################################
# Effectors
###############################################

self.poses_ships = self.create_publisher(position, f"/{world_name}/ships_poses", 10)

###############################################
# Callbacks
###############################################

def camera_callback(self, msg):
self.received_img = msg

def imu_callback(self, msg):
self.imu = msg


###############################################
# Algorithms
###############################################

def ucuv_algo (self):
img_segmented = self.segmentation(self.received_img)
poses_ships = self.track_other_ships(img_segmented, self.imu)

self.vesselCmd_pub.publish(poses_ships)


def segmentation(self):
# Algo 1
return img_segmented


def track_other_ships(self):
# Algo 2
return poses_ships

self.ucuv_algo()
