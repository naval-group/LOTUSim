# %%
import rclpy
from rclpy.node import Node
from rclpy.action import ActionClient

from std_msgs.msg import String
from geometry_msgs.msg import Pose
from geographic_msgs.msg import GeoPoint
from lotusim_msgs.msg import MASCmd as MASCmdMsg, VesselPositionArray
from lotusim_msgs.action import MASCmd

# %% [markdown]
# Currently, the model is generated by model string and not looked up through the assets. This is due to the lotusim_params section that is customized.

# %% [markdown]
# The messages (string,MASCmdArray,VesselPositionArray) are in the interface folder. Please open it.
#
# In MASCmdArray, the message is divided into goal, result, feedback while its running. We are mainly interested in the goal and result msg
# ```
# std_msgs/Header header
# MASCmd[] cmd
# ---
# bool[] result
# string[] name
# uint16[] entity
# ---
# bool fb
# ```
#
# Each message is treated like a class variable. To access the MASCmd under goal, use `msg.cmd` too access.
#
# Below are example of publisher, subscriber and action server.

# %%
class ExampleNode(Node):
    def __init__(self):
        super().__init__('example_node')
        self.pose_subscription = self.create_subscription(
            VesselPositionArray,
            'lotusim/poses',
            self.poses_callback,
            10)
        self.random_publisher = self.create_publisher(String, 'topic', 10)
        self.mas_action_client = ActionClient(self, MASCmd, '/lotusim/mas_cmd')

    def poses_callback(self, msg):
        for vessel_position in msg.vessels:
                lat = vessel_position.geo_point.latitude
                long = vessel_position.geo_point.longitude
                self.get_logger().info(
                    f"Vessel: {vessel_position.vessel_name} | latitude: {lat:.5f} | longitude: {long:.5f} "
                )


    def send_rando_string(self):
        msg = String()
        self.random_publisher.publish(msg)
    
    def send_mas_cmd(self):
        goal_msg = MASCmd.Goal()
       
        msg = MASCmdMsg()
        msg.cmd_type =  MASCmdMsg.CREATE_CMD
        msg.model_name =  "dtmb_hull"
        msg.vessel_name =  "dtmb1"        
        latlong_msg = GeoPoint()
        latlong_msg.latitude = 1.2605794416293148
        latlong_msg.longitude = 103.7516212463379
        latlong_msg.altitude = 0.0
        msg.geo_point = latlong_msg
        
        msg.sdf_string = """
<lotus_param>
    <waypoint_follower>
        <follower>
            <loop>true</loop>
            <linear_accel_limit>0.5</linear_accel_limit>
            <angular_accel_limit>0.005</angular_accel_limit>
            <angular_velocities_limits>0.01</angular_velocities_limits>
            <range_tolerance>2</range_tolerance>
            <circle>
                <radius>10</radius>
            </circle>
        </follower>
    </waypoint_follower>
</lotus_param>
"""

        goal_msg.cmd = msg

        self.mas_action_client.wait_for_server()

        return self.mas_action_client.send_goal_async(goal_msg)


def main(args=None):
    if not rclpy.ok(): 
        rclpy.init(args=args)

    node = ExampleNode()
    node.send_mas_cmd()

    try:
        rclpy.spin(node)
    except KeyboardInterrupt:
        node.get_logger().info("Shutting down...")
    finally:
        node.destroy_node()
        rclpy.shutdown()

# %%
main()
# Out:
# [INFO] [1755928395.911537586] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928395.913799729] [example_node]: Vessel: frigate | latitude: 1.24218 | longitude: 103.71979
# [INFO] [1755928396.079305239] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928396.083130068] [example_node]: Vessel: frigate | latitude: 1.24218 | longitude: 103.71979
# [INFO] [1755928396.274206836] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928396.276864428] [example_node]: Vessel: frigate | latitude: 1.24218 | longitude: 103.71978
# [INFO] [1755928396.475611933] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928396.479692629] [example_node]: Vessel: frigate | latitude: 1.24218 | longitude: 103.71978
# [INFO] [1755928396.675403297] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928396.678219430] [example_node]: Vessel: frigate | latitude: 1.24218 | longitude: 103.71977
# [INFO] [1755928396.877486545] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71980
# [INFO] [1755928396.880708691] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71977
# [INFO] [1755928397.076615716] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928397.079155096] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71977
# [INFO] [1755928397.275910392] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928397.279260901] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71976
# [INFO] [1755928397.477397723] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928397.481463437] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71976
# [INFO] [1755928397.678310199] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928397.682323624] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71976
# [INFO] [1755928397.877919604] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928397.881414683] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71976
# [INFO] [1755928398.079466592] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71981
# [INFO] [1755928398.086964990] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71975
# [INFO] [1755928398.279331744] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71982
# [INFO] [1755928398.281304593] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71975
# [INFO] [1755928398.477155371] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71982
# [INFO] [1755928398.480377409] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71975
# [INFO] [1755928398.678799588] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71982
# [INFO] [1755928398.682899584] [example_node]: Vessel: frigate | latitude: 1.24217 | longitude: 103.71975
# [INFO] [1755928398.878798552] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71982
# [INFO] [1755928398.882280872] [example_node]: Vessel: frigate | latitude: 1.24216 | longitude: 103.71974
# [INFO] [1755928399.080109695] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71983
# [INFO] [1755928399.084687244] [example_node]: Vessel: frigate | latitude: 1.24216 | longitude: 103.71974
# [INFO] [1755928399.276595719] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71983
# [INFO] [1755928399.280545697] [example_node]: Vessel: frigate | latitude: 1.24216 | longitude: 103.71974
# [INFO] [1755928399.479941683] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71983
# [INFO] [1755928399.484863086] [example_node]: Vessel: frigate | latitude: 1.24215 | longitude: 103.71974
# [INFO] [1755928399.678602352] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71984
# [INFO] [1755928399.682664786] [example_node]: Vessel: frigate | latitude: 1.24215 | longitude: 103.71974
# [INFO] [1755928399.880324229] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71984
# [INFO] [1755928399.884463137] [example_node]: Vessel: frigate | latitude: 1.24215 | longitude: 103.71974
# [INFO] [1755928400.079774404] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71985
# [INFO] [1755928400.082907677] [example_node]: Vessel: frigate | latitude: 1.24214 | longitude: 103.71973
# [INFO] [1755928400.280412564] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71985
# [INFO] [1755928400.284194984] [example_node]: Vessel: frigate | latitude: 1.24214 | longitude: 103.71973
# [INFO] [1755928400.480361646] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71985
# [INFO] [1755928400.484058761] [example_node]: Vessel: frigate | latitude: 1.24214 | longitude: 103.71973
# [INFO] [1755928400.680490288] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71986
# [INFO] [1755928400.684442594] [example_node]: Vessel: frigate | latitude: 1.24213 | longitude: 103.71973
# [INFO] [1755928400.881114231] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71986
# [INFO] [1755928400.885605795] [example_node]: Vessel: frigate | latitude: 1.24213 | longitude: 103.71973
# [INFO] [1755928401.080764081] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71986
# [INFO] [1755928401.084487698] [example_node]: Vessel: frigate | latitude: 1.24212 | longitude: 103.71973
# [INFO] [1755928401.275319235] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71987
# [INFO] [1755928401.277523425] [example_node]: Vessel: frigate | latitude: 1.24212 | longitude: 103.71973
# [INFO] [1755928401.480739996] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71987
# [INFO] [1755928401.485782772] [example_node]: Vessel: frigate | latitude: 1.24212 | longitude: 103.71972
# [INFO] [1755928401.679831022] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71987
# [INFO] [1755928401.683783662] [example_node]: Vessel: frigate | latitude: 1.24212 | longitude: 103.71972
# [INFO] [1755928401.880298888] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71988
# [INFO] [1755928401.883382201] [example_node]: Vessel: frigate | latitude: 1.24211 | longitude: 103.71972
# [INFO] [1755928402.076884489] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71988
# [INFO] [1755928402.080612885] [example_node]: Vessel: frigate | latitude: 1.24211 | longitude: 103.71972
# [INFO] [1755928402.281600832] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71988
# [INFO] [1755928402.286093313] [example_node]: Vessel: frigate | latitude: 1.24211 | longitude: 103.71972
# [INFO] [1755928402.481106454] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71988
# [INFO] [1755928402.485068311] [example_node]: Vessel: frigate | latitude: 1.24211 | longitude: 103.71972
# [INFO] [1755928402.680486400] [example_node]: Vessel: dtmb1 | latitude: 1.24210 | longitude: 103.71988
# [INFO] [1755928402.684431299] [example_node]: Vessel: frigate | latitude: 1.24211 | longitude: 103.71971
# [INFO] [1755928402.877146345] [example_node]: Shutting down...
